# %% [markdown]
# <a href="https://colab.research.google.com/github/arsanchai-su/microplastic-detection-app/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.6/609.6 kB 7.0 MB/s eta 0:00:00

# %%
#This command for download our train weigth
# !wget https://raw.github.com/arsanchai-su/microplastic-detection-app/main/weights/microplastic-detection-yolo8m.pt
# Out:
# --2023-08-21 16:15:27--  https://raw.github.com/arsanchai-su/microplastic-detection-app/main/weights/microplastic-detection-yolo8m.pt
# Resolving raw.github.com (raw.github.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.github.com (raw.github.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://raw.githubusercontent.com/arsanchai-su/microplastic-detection-app/main/weights/microplastic-detection-yolo8m.pt [following]
# --2023-08-21 16:15:27--  https://raw.githubusercontent.com/arsanchai-su/microplastic-detection-app/main/weights/microplastic-detection-yolo8m.pt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
#Download example image
# !wget https://raw.github.com/arsanchai-su/microplastic-detection-app/main/images/example1.png
# Out:
# --2023-08-21 16:15:34--  https://raw.github.com/arsanchai-su/microplastic-detection-app/main/images/example1.png
# Resolving raw.github.com (raw.github.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.github.com (raw.github.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://raw.githubusercontent.com/arsanchai-su/microplastic-detection-app/main/images/example1.png [following]
# --2023-08-21 16:15:34--  https://raw.githubusercontent.com/arsanchai-su/microplastic-detection-app/main/images/example1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 654158 (639K) [image/png]
# Saving to: ‘example1.png’
#
# ...

# %%
#Inferance example
from PIL import Image
from ultralytics import YOLO
from IPython.display import display

# Load a pretrained YOLOv8n model
model = YOLO('/content/microplastic-detection-yolo8m.pt')

# Run inference on 'bus.jpg'
results = model('/content/example1.png')  # results list

# Show the results
for i, r in enumerate(results):
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array)  # RGB PIL image
    display(im)  # show image
    im.save(f'results.jpg')  # save image with a unique name
# Out:
# image 1/1 /content/example1.png: 640x640 2 fibers, 4 films, 5 fragments, 5 pallets, 2769.6ms
# Speed: 18.2ms preprocess, 2769.6ms inference, 28.0ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=778x806>
